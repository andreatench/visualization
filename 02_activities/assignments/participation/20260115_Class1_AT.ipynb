# %% [markdown]
# What is good visulaization?
#
# #1 - Life expectancy
#
# Is the visualization pleasing to look at?
# Unnescessary three dimensional layout and shadows
# Colours are okay and help with differentiating
# Font doesn't need to be famcy
#
#
# Does the visualization accurately represent data?
# The scale is a bit odd
#
# Can we understand what message the maker of the visualization is attempting to convey?
# Somewhat but could be simiplified
#
# Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
# I don't think so. I think the shadow and 3D is not needed and makes the graph more difficult to interpret. The bars on an angle make it more difficult to compare between the continents. The scale is a bit odd on the interval.
#
#
# #2 Monstorous cost
# - it is interesting to look at but a bit confusing at first to realize it is a graph
# The axes aren't labeled
# Title not informative
# On an angle is a bit hard to compare
#
# #3
# We don't know what is being plotted or compared as value and X are not defined and we don’t know what the two different lines are
# No title
#
# #4
# % could be centered
# Not accurate - not 100%
# Sizes are the same
#
# #5
# Map
# It would be more easily interpreted if it had colours and not just shades of gray
# It is nice to look at
# Has source
# Animation is nice

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install scipy

# %%
##installed scipy and requests in terminal

# %%
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y, edgecolor = 'black')
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}


fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth',fontdict = font2)
ax.set_xlabel('Years since start',fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth',fontdict = font2)
ax.set_xlabel('Years since start',fontdict = font2)
##fig.tight_layout()
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,
           y,
           marker='*',
           color="pink")
fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/867097469.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
           y,
           marker='*',
           color="purple",
           linestyle = '--',
           linewidth = 2)
fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/3620484575.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
           y,
           marker='*',
           color="#7425b9",
           linestyle = '--',
           linewidth = 2)
fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/687889252.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
           y,
           marker='*',
           markersize = 12,
           color="#7425b9",
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#fa9359',
           markerfacecolor = '#000000'
           )
fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/3614953923.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
           y,
           marker='*',
           markersize = 12,
           color="#7425b9",
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#fa9359',
           markerfacecolor = '#000000'
           )
ax.grid(axis = 'y')

fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/2500630364.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
           y,
           marker='*',
           markersize = 12,
           color="#7425b9",
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#fa9359',
           markerfacecolor = '#000000'
           )
ax.grid(axis = 'y',
        color= 'red',
          linestyle = '--',
          linewidth =0.5)

ax.grid(axis = 'x',
        color= 'red',
          linestyle = '--',
          linewidth =0.5)

fig.show()
# Out:
# /var/folders/qw/s6_xywqs32sc_ry_ds3gyx200000gn/T/ipykernel_10597/2375420783.py:22: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Visit the Python Graph Gallery at https://python-graph-gallery.com/all-charts/
# Select one of the visualization types that you find most interesting
# For your visualization of choice:
# i. Copy the provided code and
# attempt to replicate the output in Python. NOTE: You
# may have to install packages.
# ii. Recall the aesthetic , substantive , and perceptual qualities of d
# ata
# visualizations. Does your visualization of choice succeed in each area?

# %%
# libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
 
# Create a dataset
my_count=["France","Australia","Japan","USA","Germany","Congo","China","England","Spain","Greece","Marocco","South Africa","Indonesia","Peru","Chili","Brazil"]
df = pd.DataFrame({
"country":np.repeat(my_count, 10),
"years":list(range(2000, 2010)) * 16,
"value":np.random.rand(160)
})
 
# Create a grid : initialize it
g = sns.FacetGrid(df, col='country', hue='country', col_wrap=4, )

# Add the line over the area with the plot function
g = g.map(plt.plot, 'years', 'value')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'years', 'value', alpha=0.2).set_titles("{col_name} country")
 
# Control the title of each facet
g = g.set_titles("{col_name}")
 
# Add a title for the whole plot
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Evolution of the value of stuff in 16 countries')

# Show the graph
plt.show()

# %% [markdown]
# aesthetic - it is pretty and easy to read
#
# substantive - don't know the source of the data
#
# perceptual - value and years are clear but don't know what "stuff is
